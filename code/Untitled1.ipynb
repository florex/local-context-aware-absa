# %%
from google.colab import drive
drive.mount('/content/gdrive')

import json

# %%
with open("/content/gdrive/MyDrive/absa_carmel/data/cross_lingual/statistic_aspect_fr.json") as f:
  data=json.loads(f.read())

import pandas as pd
pd_data=pd.DataFrame(data)
df = (pd_data.T)
df.to_excel('/content/gdrive/MyDrive/absa_carmel/data/cross_lingual/statistic_aspect_fr.xlsx')
