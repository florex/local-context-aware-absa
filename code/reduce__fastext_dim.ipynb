# %%
# !pip install -q kaggle
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a6618fbf-a222-4e4e-b02d-13fd1f269cac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a6618fbf-a222-4e4e-b02d-13fd1f269cac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"apachefranklin","key":"31655bbb5eec2971ba54f88080ce7b01"}'}

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                          title                                           size  lastUpdated          downloadCount
# -----------------------------------------------------------  ---------------------------------------------  -----  -------------------  -------------
# alexgude/california-traffic-collision-data-from-switrs       California Traffic Collision Data from SWITRS    1GB  2020-11-22 16:51:55           1242
# babyoda/women-entrepreneurship-and-labor-force               Women Entrepreneurship and Labor Force           1KB  2020-11-21 08:38:51           3070
# szymonjanowski/internet-articles-data-with-users-engagement  Internet news data with readers engagement       3MB  2020-11-21 17:09:57           1483
# sakshigoyal7/credit-card-customers                           Credit Card customers                          379KB  2020-11-19 07:38:44           5892
# ...

# %%
# !kaggle datasets download  'ccen-fr50bin'
# Out:
# ...
#  99% 1.40G/1.42G [00:28<00:00, 55.1MB/s]
# 100% 1.42G/1.42G [00:28<00:00, 53.7MB/s]

# %%
# !unzip ccen-fr50bin.zip
# Out:
# Archive:  ccen-fr50bin.zip
#   inflating: cc.en.50.bin
#   inflating: cc.fr.50.bin

# %%
# !cp cc.en.50.bin /content/gdrive/MyDrive/absa_carmel/data/word_representation/
# !cp cc.fr.50.bin /content/gdrive/MyDrive/absa_carmel/data/word_representation/

# %%
# !pip install fasttext
import fasttext
import fasttext.util
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ...
#      |████████████████████████████████| 71kB 5.2MB/s
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp36-cp36m-linux_x86_64.whl size=3042152 sha256=aeb055c7d11840bea30a2ce751bef3effe11775f905916fa1b112e0d28a80fba
#   Stored in directory: /root/.cache/pip/wheels/98/ba/7f/b154944a1cf5a8cee91c154b75231136cc3a3321ab0e30f592
# Successfully built fasttext
# ...
# Mounted at /content/gdrive

# %%
cp

# %%
model_ted_fr["dolé"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-e48af5417be3> in <module>()
# ----> 1 model_ted_fr["dolé"]
#
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py in __getitem__(self, entities)
#     335         if isinstance(entities, string_types):
#     336             # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 337             return self.get_vector(entities)
#     338
#     339         return vstack([self.get_vector(entity) for entity in entities])
#
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py in get_vector(self, word)
#     453
#     454     def get_vector(self, word):
# --> 455         return self.word_vec(word)
#     456
#     457     def words_closer_than(self, w1, w2):
#
# ...
